# %% [markdown]
# <a href="https://colab.research.google.com/github/Avinash505/AIandMachinlearning/blob/main/Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Iris Flowers Classification Project
# Project idea – The iris flowers have different species and you can distinguish them based on the length of petals and sepals.
#
# This is a basic project for machine learning beginners to predict the species of a new iris flower.
#
# Here we take a data set call 'iris' from sns
#
# sns is seaborn library
#
# Seaborn is a library for making statistical graphics in Python. It builds on top of matplotlib and integrates closely with pandas data structures.

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# #Features of the dataset

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
sns.catplot(x = 'species', y = 'sepal_length', data = df)

# %%
sns.catplot(x = 'species', y = 'petal_length', data = df, kind = 'violin')

# %%
sns.catplot(x = 'species', y = 'sepal_width', data= df, kind='swarm')

# %%
sns.catplot(x = 'species', y = 'petal_width', data= df, kind='swarm')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 28.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.distplot(df['sepal_length'])
# KDE- kernal density estimation
# estimates probsbility density of curve which have 1/more continuous var
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set_style('darkgrid')
sns.distplot(df['sepal_length'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.jointplot(x = 'petal_length',y = 'petal_width', data = df, color='g')

# %%
sns.jointplot(x = 'petal_length',y = 'petal_width', kind = 'kde' ,data = df, color='m')

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue='species')

# %%
sns.pairplot(df, hue='species', vars = ['sepal_length','petal_length'])

# %%
X = df.iloc[:,[0,1,2,3]]
y = df['species']
X.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
y[:5]
# Out:
# 0    setosa
# 1    setosa
# 2    setosa
# 3    setosa
# 4    setosa
# Name: species, dtype: object

# %% [markdown]
# #KNN (K-Nearest Neighbour) METHOD

# %%
### Apply knn for IRIS Dataset
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors =3)
knn
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
knn.fit(X,y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_prediction = knn.predict(X)
y_prediction
# Out:
# array(['setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'virginica', 'versicolor', 'virginica', 'versicolor',
# ...

# %% [markdown]
# #Predicting Accuracy in KNN method 1

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y,y_prediction)
# Out:
# 0.96

# %%
knn1 = KNeighborsClassifier(n_neighbors = 5) # if n_neighbors = 10....accuracy_score=0.98
knn1
# Out:
# KNeighborsClassifier()

# %%
knn1.fit(X,y)
# Out:
# KNeighborsClassifier()

# %%
y_prediction1 = knn1.predict(X)

# %% [markdown]
# ##Predicting Accuracy in KNN method 2

# %%
accuracy_score(y,y_prediction1)
# Out:
# 0.9666666666666667

# %%
knn1.predict([[3.1,3.5,5.4,0.2]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# array(['versicolor'], dtype=object)

# %% [markdown]
# ##SVM (Support Vector Machine) MODEL

# %%
from sklearn.svm import SVC

# %%
svm = SVC()
svm
# Out:
# SVC()

# %%
svm = SVC(kernel='rbf')
svm
# Out:
# SVC()

# %%
svm.fit(X,y)
# Out:
# SVC()

# %%
y_prediction2 = svm.predict(X)
y_prediction2
# Out:
# array(['setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
# ...

# %% [markdown]
# ##predicting accuracy in SVM method 1

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y, y_prediction2)
# Out:
# 0.9733333333333334

# %%
svm1 = SVC(kernel='linear')
svm1
# Out:
# SVC(kernel='linear')

# %%
svm1.fit(X,y)
# Out:
# SVC(kernel='linear')

# %%
svm1.fit(X,y)
# Out:
# SVC(kernel='linear')

# %%
y_prediction3 = svm1.predict(X)
y_prediction3
# Out:
# array(['setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
# ...

# %% [markdown]
# ##predicting accuracy in SVM method 2

# %%
accuracy_score(y, y_prediction3)
# Out:
# 0.9933333333333333

# %%
svm2 = SVC(kernel='poly')
svm2
# Out:
# SVC(kernel='poly')

# %%
svm2.fit(X,y)
# Out:
# SVC(kernel='poly')

# %%
y_prediction4 = svm2.predict(X)
y_prediction4
# Out:
# array(['setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'virginica', 'versicolor', 'virginica', 'versicolor',
# ...

# %% [markdown]
# #predicting accuracy in SVM method 3

# %%
accuracy_score(y, y_prediction4)
# Out:
# 0.9733333333333334

# %% [markdown]
# #CONCLUSION
# In this project we undestand how KNN method and SVM method are used to find the accuracy.
#
# We predicted accuracy in different possible way for each method to understand the model clearly.
